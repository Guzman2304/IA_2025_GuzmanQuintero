# %% [markdown]
# <a href="https://colab.research.google.com/github/Guzman2304/IA_2025_GuzmanQuintero/blob/main/Untitled22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Objetivo de estudio
# 2. Exploracion de datos EDA
# 3. Limpieza de datos
# 4. entrenar el modelo(arbol de decicion)
# 5. Evaluar el modelo

# %%
# Tratamiento de datos
import numpy as np
import pandas as pd

# Gráficos
import matplotlib.pyplot as plt

# Preprocesado y modelado
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import mean_squared_error, r2_score

# %%
datos=pd.read_csv('https://raw.githubusercontent.com/rpizarrog/Analisis-Inteligente-de-datos/main/datos/Advertising_Web.csv')
datos.head()
# Out:
#    Unnamed: 0  X     TV  Radio  Newspaper         Web  Sales
# 0           1  1  230.1   37.8       69.2  306.634752   22.1
# 1           2  2   44.5   39.3       45.1  302.653070   10.4
# 2           3  3   17.2   45.9       69.3   49.498908    9.3
# 3           4  4  151.5   41.3       58.5  257.816893   18.5
# 4           5  5  180.8   10.8       58.4  195.660076   12.9

# %%
import matplotlib.pyplot as plt

# TV vs Sales
plt.scatter(datos['TV'], datos['Sales'])
plt.xlabel('TV Advertising Spending')
plt.ylabel('Sales')
plt.title('TV Advertising Spending vs Sales')
plt.show()

# Radio vs Sales
plt.scatter(datos['Radio'], datos['Sales'])
plt.xlabel('Radio Advertising Spending')
plt.ylabel('Sales')
plt.title('Radio Advertising Spending vs Sales')
plt.show()

# Newspaper vs Sales
plt.scatter(datos['Newspaper'], datos['Sales'])
plt.xlabel('Newspaper Advertising Spending')
plt.ylabel('Sales')
plt.title('Newspaper Advertising Spending vs Sales')
plt.show()

# Web vs Sales
plt.scatter(datos['Web'], datos['Sales'])
plt.xlabel('Web Advertising Spending')
plt.ylabel('Sales')
plt.title('Web Advertising Spending vs Sales')
plt.show()

# %% [markdown]
# ##2. Exploracion de datos EDA:

# %%
print("Observaciones y variables:", datos.shape)
# Out:
# Observaciones y variables: (200, 7)

# %%
datos.dtypes
# Out:
# Unnamed: 0      int64
# X               int64
# TV            float64
# Radio         float64
# Newspaper     float64
# Web           float64
# Sales         float64
# dtype: object

# %%
datos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   X           200 non-null    int64
#  2   TV          200 non-null    float64
#  3   Radio       200 non-null    float64
#  4   Newspaper   200 non-null    float64
#  5   Web         200 non-null    float64
#  6   Sales       200 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 11.1 KB

# %% [markdown]
# Se describen como variables independientes TV, Radio,Newspaper y Web y como variable dependiente Sales:
#
#
# Las variables independientes son:
# * TV= costos de publicidad en TV (miles de dolares)
# * Radio= costos de publicidad inertidos en medios de difucion radio(miles de dolarea)
# * Newspaper= costos publicitarios para medios impresos
# * Web= publicitarios en herramientas digitales

# %% [markdown]
# Limpieza de datos

# %%
datos=datos[["TV","Radio","Newspaper","Web","Sales"]]
datos.describe()
# Out:
#                TV       Radio   Newspaper         Web       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000  159.587355   14.022500
# std     85.854236   14.846809   21.778621   76.815266    5.217457
# min      0.700000    0.000000    0.300000    4.308085    1.600000
# 25%     74.375000    9.975000   12.750000   99.048767   10.375000
# 50%    149.750000   22.900000   25.750000  156.862154   12.900000
# 75%    218.825000   36.525000   45.100000  212.311848   17.400000
# max    296.400000   49.600000  114.000000  358.247042   27.000000

# %% [markdown]
# Datos de entrenamiento y datos de validacion

# %% [markdown]
# Se emplearan la semila 1279(random_state=2022) los datos se destribuiran de la siguiente manera
#
#
# 1.   70% oara entrenamiento
# 2.   30% para calidacion del modelo

# %%
X_entrena,X_valida,Y_entrena,Y_calida=train_test_split(datos.drop(columns="Sales"),datos["Sales"],train_size=.7,random_state=1279)

# %%
X_entrena.shape
# Out:
# (140, 4)

# %% [markdown]
# ##4.1 MODELANDO EL ARBOL DE DECISIONES
#
# La clase de decisionTreeRegressor del modulo sklearn.tree tiene los siguientes parametros:
#
# * Max_depth: profundidad mazima que puede alcanzar el arvol.
# * min_samples_split: numero minimo de observaciones que debe detener el nodo para que pueda dividirse. Si el calor decimal se interpreta como la draccion total de observaciones de entrenamiento ceil
# (min_samples_spilth*n samples)
# * min_samples_ñeaf: numero minimo de observaciones que deben tener cada uno de los nodos hijos para que se produzca una division

# %%
modelo_ar=DecisionTreeRegressor(max_depth=3,random_state=2022)

# %% [markdown]
# Usamos los datos de entrenamiento

# %%
modelo_ar.fit(X_entrena,Y_entrena)
# Out:
# DecisionTreeRegressor(max_depth=3, random_state=2022)

# %% [markdown]
# ## VISUALIZACION DEL MODELO

# %%
print(f"Profundidad del arbol:{modelo_ar.get_depth()}")
print(f"Numero de nodos terminales:{modelo_ar.get_n_leaves()}")
# Out:
# Profundidad del arbol:3
# Numero de nodos terminales:8

# %%
plt.figure(figsize=(20, 10))
plot_tree(modelo_ar, feature_names=X_entrena.columns, filled=True, rounded=True)
plt.show()

# %%
text_modelo=export_text(decision_tree=modelo_ar,feature_names=datos.drop(columns="Sales").columns)
print(text_modelo)
# Out:
# |--- TV <= 140.80
# |   |--- TV <= 30.05
# |   |   |--- TV <= 15.00
# |   |   |   |--- value: [4.95]
# |   |   |--- TV >  15.00
# |   |   |   |--- value: [8.23]
# |   |--- TV >  30.05
# |   |   |--- Radio <= 13.30
# |   |   |   |--- value: [9.80]
# |   |   |--- Radio >  13.30
# |   |   |   |--- value: [12.34]
# |--- TV >  140.80
# |   |--- Radio <= 26.95
# |   |   |--- Radio <= 10.05
# |   |   |   |--- value: [12.06]
# |   |   |--- Radio >  10.05
# |   |   |   |--- value: [15.70]
# |   |--- Radio >  26.95
# |   |   |--- Radio <= 41.40
# |   |   |   |--- value: [19.47]
# |   |   |--- Radio >  41.40
# |   |   |   |--- value: [23.65]

# %% [markdown]
# ## PREDICCIONES
# La importancia de cada rpedictor en el modelo se calcula como la reduccion total(normalizada) en el criterio de division. en el caso, el mse qie se consifue el predictor enlas divisiones en las que participa, si un predictor no se ha seleccionado ninfina division no se incluye en el modelado y us importancia es 0

# %%
importancia_predictores=pd.DataFrame({"predictor":datos.drop(columns="Sales").columns,"importancia":modelo_ar.feature_importances_})

# %%
importancia_predictores.sort_values(by="importancia",ascending=False)
# Out:
#    predictor  importancia
# 0         TV     0.626264
# 1      Radio     0.373736
# 2  Newspaper     0.000000
# 3        Web     0.000000
